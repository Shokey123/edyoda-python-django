# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get("https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")
print(response)
# Out:
# <Response [200]>

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.content)
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.82a2ce.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pr
# ...

# %%
soup = BeautifulSoup(response.content,"html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.82a2ce.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
title = soup.find("div", attrs = {"_3wU53n"})
print(title.text)
# Out:
# HP Pavilion Ryzen 5 Quad Core - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/3 GB Graphics) 15-ec0026AX G...

# %%
titles = soup.find_all("div", attrs = {"_3wU53n"})

for title in titles:
    print(title.text)
# Out:
# HP Pavilion Ryzen 5 Quad Core - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/3 GB Graphics) 15-ec0026AX G...
# Asus VivoBook 14 Core i3 7th Gen - (4 GB/256 GB SSD/Windows 10 Home) X412UA-EK340T Thin and Light Lapt...
# Avita Liber Core i5 8th Gen - (8 GB/256 GB SSD/Windows 10 Home) NS14A2IN197P Thin and Light Laptop
# Apple MacBook Air Core i5 5th Gen - (8 GB/128 GB SSD/Mac OS Sierra) MQD32HN/A A1466
# Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SSD/Windows 10 Home/2 GB Graphics) SF314-55G Thin and Ligh...
# Acer Aspire 5s Core i5 8th Gen - (8 GB/512 GB SSD/Windows 10 Home/2 GB Graphics) A515-54G Thin and Lig...
# HP 15q APU Dual Core A9 - (4 GB/1 TB HDD/Windows 10 Home) 15q-dy0007AU Laptop
# Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 TB HDD/Windows 10 Home) 130-15IKB Laptop
# Dell Vostro 3000 Core i5 8th Gen - (8 GB/1 TB HDD/Windows 10 Home) 3480 Laptop
# Acer Aspire 3 Ryzen 3 Dual Core - (4 GB/1 TB HDD/Windows 10 Home) A315-42-R414 Laptop
# ...

# %%
price = soup.find("div", attrs = {"_1vC4OE _2rQ-NK"})
print(price.text)
# Out:
# ₹55,940

# %%
prices = soup.find_all("div", attrs = {"_1vC4OE _2rQ-NK"})
for price in prices:
    print(price.text)
# Out:
# ₹55,940
# ₹33,990
# ₹41,990
# ₹57,990
# ₹49,990
# ₹49,990
# ₹22,990
# ₹27,990
# ₹38,990
# ₹23,990
# ₹33,990
# ₹43,990
# ₹31,990
# ₹28,990
# ₹849
# ₹66,990
# ₹28,990
# ₹27,990
# ₹32,490
# ₹27,990
# ₹54,900
# ₹24,990
# ₹18,990
# ₹26,990

# %%
rating = soup.find("div", attrs = {"hGSR34"})
print(rating.text)
# Out:
# 5

# %%
ratings = soup.find_all("div", attrs = {"hGSR34"})
for rating in ratings:
    print(rating.text)
# Out:
# 5
# 4.3
# 4.5
# 4.7
# 4.6
# 4.5
# 4.1
# 4.1
# 4.1
# 4.1
# 4.3
# 4.3
# 4.2
# 4.2
# 4.2
# 4.5
# 4.1
# 3.7
# 4.3
# 4
# 4.6
# 4.1
# 4.1
# 4
# 4.6
# 5
# 5
# 4.1
# 4
# 4
# 4.7
# 5
# 4
# 4.1
# 5
# 4
# 4.2
# 4
# 5

# %%
review = soup.find("div", attrs = {"qwjRop"})
print(review.text)
# Out:
# performance is awesome when connected to the charger.boot time is 8 second.battery backup around 5 hour.cpu z single thread point is 430 and multicore poi...Read full review

# %%
reviews = soup.find_all("div", attrs = {"qwjRop"})
for review in reviews:
    print(review.text)
    print("\n\n")
# Out:
# performance is awesome when connected to the charger.boot time is 8 second.battery backup around 5 hour.cpu z single thread point is 430 and multicore poi...Read full review
#
#
#
# Nice device, very powerful. Eventhough the speaker need to be little good. I use it for programming and gaming. No performance issue as right now.Read full review
#
#
#
# processing slow due to Windows 10 installed. if install linux , the processing speed much more 2x fast then windows 10. actually this is a linux based laptop.Read full review
#
#
#
# 1.Purchased for16k. Good choice for office purpose. 2.All softwares installed are only trail versions3. back up is good. Up to 3 movies4.below 1 GB games g...Read full review
#
#
#
# dream come true. .ordered with 1 tb hdd to resolve less storage. birthday gift for my bro. very thin and light weight.Read full review
#
#
#
# ...

# %%
cart = soup.find("div", attrs = {"_1-2Iqu row"})
print(cart.text)
# Out:
# HP Pavilion Ryzen 5 Quad Core - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/3 GB Graphics) 15-ec0026AX G...53 Ratings & 0 ReviewsAMD Ryzen 5 Quad Core Processor8 GB DDR4 RAM64 bit Windows 10 Operating System1 TB HDD|256 GB SSD39.62 cm (15.6 inch) Display1 Year Onsite Warranty₹55,940₹64,31413% off

# %%
carts = soup.find_all("div", attrs = {"class":"_1-2Iqu row"})
for cart in carts:
    
    title = cart.find("div", attrs = {"_3wU53n"})
    price = soup.find("div", attrs = {"_1vC4OE _2rQ-NK"})
    rating = soup.find("div", attrs = {"hGSR34"})
    review = soup.find("div", attrs = {"qwjRop"})
    
    
    print("Laptop: {} \n price: {} \n rating: {} \n Review: {} \n\n".format(title.text, price.text, rating.text, review.text))
    

    
#     print("{} {} {} {} ".format(title.text, price.text, rating.text, review.text))
# Out:
# Laptop: HP Pavilion Ryzen 5 Quad Core - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/3 GB Graphics) 15-ec0026AX G...
#  price: ₹55,940
#  rating: 5
#  Review: performance is awesome when connected to the charger.boot time is 8 second.battery backup around 5 hour.cpu z single thread point is 430 and multicore poi...Read full review
#
#
# Laptop: Asus VivoBook 14 Core i3 7th Gen - (4 GB/256 GB SSD/Windows 10 Home) X412UA-EK340T Thin and Light Lapt...
#  price: ₹55,940
#  rating: 5
#  Review: performance is awesome when connected to the charger.boot time is 8 second.battery backup around 5 hour.cpu z single thread point is 430 and multicore poi...Read full review
#
#
# Laptop: Avita Liber Core i5 8th Gen - (8 GB/256 GB SSD/Windows 10 Home) NS14A2IN197P Thin and Light Laptop
#  price: ₹55,940
#  rating: 5
#  Review: performance is awesome when connected to the charger.boot time is 8 second.battery backup around 5 hour.cpu z single thread point is 430 and multicore poi...Read full review
#
# ...
